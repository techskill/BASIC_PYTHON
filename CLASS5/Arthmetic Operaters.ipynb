# %% [markdown]
# # Arthmetic Operators

# %% [markdown]
# ## Addition

# %%
popular_number = 4+4
popular_number
# Out:
# 8

# %% [markdown]
# ## Sutraction

# %%
popular_number = 4-3
popular_number
# Out:
# 1

# %% [markdown]
# ## Divison

# %%
popular_number = 4/3
popular_number
# Out:
# 1.3333333333333333

# %% [markdown]
# ## Multiplication

# %%
popular_number = 4*4
popular_number
# Out:
# 16

# %% [markdown]
# ## Exponent

# %%
popular_number = 4**3 #power
popular_number
# Out:
# 64

# %% [markdown]
# ## Modules

# %%
popular_number = 4%3 
popular_number  #this is show remider
# Out:
# 1

# %% [markdown]
# ## Floor Divison

# %%
popular_number = 4//3
popular_number #this is not show the point value
# Out:
# 1
