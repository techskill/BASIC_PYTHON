# %% [markdown]
# ## Assigement Operater

# %%
# =
# +=
# -=

# %%
age = 18
age = age +1

# %%
age
# Out:
# 19

# %%
weight = 55

# %%
weight +=1

# %%
weight
# Out:
# 56

# %%
weight -= 20

# %%
weight
# Out:
# 36

# %%
weight_1 = weight #update

# %%
weight_1 = 56

# %%
weight = weight_1

# %%
weight_1
# Out:
# 56
